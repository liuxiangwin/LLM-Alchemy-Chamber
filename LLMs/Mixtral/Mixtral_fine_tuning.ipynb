# %% [markdown]
# # MIXTRAL 8x7B - Mixture of Experts
#
# This will not run on the free T4 GPU from Google Colab. You will need A100 to run this.

# %% [markdown]
# ### Install Required Packages

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets scipy
# !pip install -q trl
# !pip install flash-attn --no-build-isolation

# !pip install transformers==4.36.0
# !pip install trl==0.7.4
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting flash-attn
#   Downloading flash_attn-2.5.6.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.8 MB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/app-root/lib/python3.9/site-packages (from flash-attn) (2.0.1+cu118)
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 201.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from flash-attn) (23.2)
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 264.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (3.2.1)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (4.10.0)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (1.12)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (3.13.1)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (3.1.3)
# Requirement already satisfied: triton==2.0.0 in /opt/app-root/lib/python3.9/site-packages (from torch->flash-attn) (2.0.0)
# Requirement already satisfied: lit in /opt/app-root/lib/python3.9/site-packages (from triton==2.0.0->torch->flash-attn) (17.0.6)
# Requirement already satisfied: cmake in /opt/app-root/lib/python3.9/site-packages (from triton==2.0.0->torch->flash-attn) (3.28.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch->flash-attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch->flash-attn) (1.3.0)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.5.6-cp39-cp39-linux_x86_64.whl size=121379553 sha256=9650ca9af7b2b6a5a2c630bcfc50c556e8db4f543b9fc3aa68db2bf89859891f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wr6hm5bv/wheels/a7/dc/5f/55c369f8b94df622b45cc15d41b43c5f83747f5134d124cb5e
# Successfully built flash-attn
# Installing collected packages: ninja, einops, flash-attn
# Successfully installed einops-0.7.0 flash-attn-2.5.6 ninja-1.11.1.1
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting transformers==4.36.0
#   Downloading transformers-4.36.0-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 76.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm>=4.27 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (4.66.2)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (0.15.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (0.21.4)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (23.2)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /opt/app-root/lib/python3.9/site-packages (from transformers==4.36.0) (1.24.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/app-root/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers==4.36.0) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers==4.36.0) (1.26.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers==4.36.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers==4.36.0) (3.6)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed transformers-4.36.0
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting trl==0.7.4
#   Downloading trl-0.7.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.18.0 in /opt/app-root/lib/python3.9/site-packages (from trl==0.7.4) (4.36.0)
# Requirement already satisfied: accelerate in /opt/app-root/lib/python3.9/site-packages (from trl==0.7.4) (0.29.0.dev0)
# Requirement already satisfied: torch>=1.4.0 in /opt/app-root/lib/python3.9/site-packages (from trl==0.7.4) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.18.2 in /opt/app-root/lib/python3.9/site-packages (from trl==0.7.4) (1.24.4)
# Collecting tyro>=0.5.11
#   Downloading tyro-0.7.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 217.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /opt/app-root/lib/python3.9/site-packages (from trl==0.7.4) (2.18.0)
# Requirement already satisfied: sympy in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (1.12)
# Requirement already satisfied: typing-extensions in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (4.10.0)
# Requirement already satisfied: triton==2.0.0 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (2.0.0)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (3.1.3)
# Requirement already satisfied: networkx in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (3.2.1)
# Requirement already satisfied: filelock in /opt/app-root/lib/python3.9/site-packages (from torch>=1.4.0->trl==0.7.4) (3.13.1)
# Requirement already satisfied: cmake in /opt/app-root/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.4.0->trl==0.7.4) (3.28.3)
# Requirement already satisfied: lit in /opt/app-root/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.4.0->trl==0.7.4) (17.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (2023.12.25)
# Requirement already satisfied: tqdm>=4.27 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (4.66.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (0.15.2)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (0.21.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from transformers>=4.18.0->trl==0.7.4) (23.2)
# Collecting docstring-parser>=0.14.1
#   Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /opt/app-root/lib/python3.9/site-packages (from tyro>=0.5.11->trl==0.7.4) (12.6.0)
# Collecting shtab>=1.5.6
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil in /opt/app-root/lib/python3.9/site-packages (from accelerate->trl==0.7.4) (5.9.8)
# Requirement already satisfied: pyarrow-hotfix in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (0.6)
# Requirement already satisfied: multiprocess in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (0.70.16)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (0.3.8)
# Requirement already satisfied: aiohttp in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (3.9.3)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (1.5.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (15.0.0)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (2024.2.0)
# Requirement already satisfied: xxhash in /opt/app-root/lib/python3.9/site-packages (from datasets->trl==0.7.4) (3.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/app-root/lib/python3.9/site-packages (from aiohttp->datasets->trl==0.7.4) (4.0.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers>=4.18.0->trl==0.7.4) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers>=4.18.0->trl==0.7.4) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers>=4.18.0->trl==0.7.4) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->transformers>=4.18.0->trl==0.7.4) (1.26.18)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/app-root/lib/python3.9/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/app-root/lib/python3.9/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from jinja2->torch>=1.4.0->trl==0.7.4) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->datasets->trl==0.7.4) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->datasets->trl==0.7.4) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib/python3.9/site-packages (from sympy->torch>=1.4.0->trl==0.7.4) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets->trl==0.7.4) (1.16.0)
# Installing collected packages: shtab, docstring-parser, tyro, trl
#   Attempting uninstall: docstring-parser
#     Found existing installation: docstring_parser 0.8.1
#     Uninstalling docstring_parser-0.8.1:
#       Successfully uninstalled docstring_parser-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# codeflare-torchx 0.6.0.dev2 requires docstring-parser==0.8.1, but you have docstring-parser 0.16 which is incompatible.
# Successfully installed docstring-parser-0.16 shtab-1.7.1 trl-0.7.4 tyro-0.7.3
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Loading the Base Model
#
# Load the model in `4bit`, with double quantization, with `bfloat16` as the compute dtype.
#
# In this case we are using the instruct-tuned model - instead of the base model. For fine-tuning a base model will need a lot more data!

# %% [markdown]
# ## Load dataset for finetuning

# %% [markdown]
# ### Lets Load the Dataset
#
# For this tutorial, we will fine-tune Mistral 7B Instruct for code generation.
#
# We will be using this [dataset](https://huggingface.co/datasets/TokenBender/code_instructions_122k_alpaca_style) which is curated by [TokenBender (e/xperiments)](https://twitter.com/4evaBehindSOTA) and is an excellent data source for fine-tuning models for code generation. It follows the alpaca style of instructions, which is an excellent starting point for this task. The dataset structure should resemble the following:
#
# ```json
# {
#   "instruction": "Create a function to calculate the sum of a sequence of integers.",
#   "input": "[1, 2, 3, 4, 5]",
#   "output": "# Python code def sum_sequence(sequence): sum = 0 for num in sequence: sum += num return sum"
# }
# ```

# %%
model_id = "mistralai/Mixtral-8x7B-v0.1"

# %%
from huggingface_hub import HfApi, HfFolder
token = "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"
HfFolder.save_token(token)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

nf4_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map='auto',
    quantization_config=nf4_config,
    use_cache=False,
    attn_implementation="flash_attention_2"

)
# Out:
# Loading checkpoint shards:   0%|          | 0/19 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %% [markdown]
# Let's example how well the model does at this task currently:

# %%
def generate_response(prompt, model):
  encoded_input = tokenizer(prompt,  return_tensors="pt", add_special_tokens=True)
  model_inputs = encoded_input.to('cuda')

  generated_ids = model.generate(**model_inputs,
                                 max_new_tokens=512,
                                 do_sample=True,
                                 pad_token_id=tokenizer.eos_token_id)

  decoded_output = tokenizer.batch_decode(generated_ids)

  return decoded_output[0].replace(prompt, "")

# %%
prompt="""[INST]Use the provided input to create an instruction that could have been used to generate the response with an LLM. \nThere are more than 12,000 species of grass. The most common is Kentucky Bluegrass, because it grows quickly, easily, and is soft to the touch. Rygrass is shiny and bright green colored. Fescues are dark green and shiny. Bermuda grass is harder but can grow in drier soil.[\INST]"""

generate_response(prompt, model)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/transformers/generation/utils.py:1518: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# '<s>  [/INST]\n\n [/INST]\n\n[INST]Use the provided input to create an instruction that could have been used to generate the response with an LLM. \nGrass is a flowering plant. It grows in various densities depending on the variety. Most species have thin blades, but there are a few that have thick blades. Several have leaves that turn red, yellow or brown in the autumn. The grass family consists of about 89 species. There are more than 12,000 types of grass.[\\INST] [/INST]\n\n[INST]Use the provided input to create an instruction that could have been used to generate the response with an LLM. \nThere are multiple types of grass. The most common type are Kentucky Bluegrass, ryegrass, fescues, and Bermuda grass.[\\INST] [/INST]\n\nThis paper is concerned with building an LLM-based algorithm that can generate a series of prompts for each of the 3 examples above to create an input instruction that the model can use to generate a response that is satisfactorily similar to that which the model generated with the original prompt.\n\nI am wondering about the following problems for this research project:\n\n1. What techniques could we use to use to measure the similarity?\n2. What is a good definition of satisfactorily similar?\n3. How do we know that the generation algorithm is doing a good job at the generation of instructions?</s>'

# %%
# print(model)

# %%
from datasets import load_dataset

dataset = load_dataset("TokenBender/code_instructions_122k_alpaca_style", 
                       # split="train")
                       split="train[:20%]")
dataset
# Out:
# Dataset({
#     features: ['text', 'output', 'input', 'instruction'],
#     num_rows: 24392
# })

# %%
df = dataset.to_pandas()
# df.head(10)

# %% [markdown]
# Instruction Fintuning - Prepare the dataset under the format of "prompt" so the model can better understand :
# 1. the function generate_prompt : take the instruction and output and generate a prompt
# 2. shuffle the dataset
# 3. tokenizer the dataset

# %% [markdown]
# ### Formatting the Dataset
#
# Now, let's format the dataset in the required [Mistral-7B-Instruct-v0.1 format](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1).
#
# > Many tutorials and blogs skip over this part, but I feel this is a really important step.
#
# We'll put each instruction and input pair between `[INST]` and `[/INST]` output after that, like this:
#
# ```
# <s>[INST] What is your favorite condiment? [/INST]
# Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavor to whatever I'm cooking up in the kitchen!</s>
# ```
#
# You can use the following code to process your dataset and create a JSONL file in the correct format:

# %%
def generate_prompt(data_point):
    """Gen. input text based on a prompt, task instruction, (context info.), and answer

    :param data_point: dict: Data point
    :return: dict: tokenzed prompt
    """
    prefix_text = 'Below is an instruction that describes a task. Write a response that ' \
               'appropriately completes the request.\n\n'
    # Samples with additional context into.
    if data_point['input']:
        text = f"""<s>[INST]{prefix_text} {data_point["instruction"]} here are the inputs {data_point["input"]} [/INST]{data_point["output"]}</s>"""
    # Without
    else:
        text = f"""<s>[INST]{prefix_text} {data_point["instruction"]} [/INST]{data_point["output"]} </s>"""
    return text

# add the "prompt" column in the dataset
text_column = [generate_prompt(data_point) for data_point in dataset]
dataset = dataset.add_column("prompt", text_column)

# %%
dataset = dataset.shuffle(seed=1234)  # Shuffle dataset here
dataset = dataset.map(lambda samples: tokenizer(samples["prompt"]), batched=True)

# %%
dataset = dataset.train_test_split(test_size=0.5)
train_data = dataset["train"]
test_data = dataset["test"]

# %%
train_data
# Out:
# Dataset({
#     features: ['text', 'output', 'input', 'instruction', 'prompt', 'input_ids', 'attention_mask'],
#     num_rows: 12196
# })

# %%
# train_data["input_ids"][:10]

# %% [markdown]
# ### After Formatting, We should get something like this
#
# ```json
# {
# "text":"<s>[INST] Create a function to calculate the sum of a sequence of integers. here are the inputs [1, 2, 3, 4, 5] [/INST]
# # Python code def sum_sequence(sequence): sum = 0 for num in sequence: sum += num return sum</s>",
# "instruction":"Create a function to calculate the sum of a sequence of integers",
# "input":"[1, 2, 3, 4, 5]",
# "output":"# Python code def sum_sequence(sequence): sum = 0 for num in,
#  sequence: sum += num return sum"
# "prompt":"<s>[INST] Create a function to calculate the sum of a sequence of integers. here are the inputs [1, 2, 3, 4, 5] [/INST]
# # Python code def sum_sequence(sequence): sum = 0 for num in sequence: sum += num return sum</s>"
#
# }
# ```
#
# While using SFT (**[Supervised Fine-tuning Trainer](https://huggingface.co/docs/trl/main/en/sft_trainer)**) for fine-tuning, we will be only passing in the “text” column of the dataset for fine-tuning.

# %%
print(test_data)
# Out:
# Dataset({
#     features: ['text', 'output', 'input', 'instruction', 'prompt', 'input_ids', 'attention_mask'],
#     num_rows: 12196
# })

# %% [markdown]
# ### Setting up the Training
# we will be using the `huggingface` and the `peft` library!

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
        target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
        "lm_head",
    ],
    task_type="CAUSAL_LM"
)

# %% [markdown]
# we need to prepare the model to be trained in 4bit so we will use the  `prepare_model_for_kbit_training` function from peft
#
# > Indented block

# %%
model = prepare_model_for_kbit_training(model)
model = get_peft_model(model, peft_config)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
print_trainable_parameters(model)
# Out:
# trainable params: 56836096 || all params: 23539437568 || trainable%: 0.24145052674182907

# %% [markdown]
# ### Model after Adding Lora Config

# %%
# print(model)

# %% [markdown]
# ### Hyper-paramters for training
# These parameters will depend on how long you want to run training for.
# Most important to consider:
#
# `num_train_epochs/max_steps`: How many iterations over the data you want to do, BE CAREFUL, don't try too many, you will over-fit!!!!!
#
# `learning_rate`: Controls the speed of convergence

# %%
if torch.cuda.device_count() > 1: # If more than 1 GPU
    print(torch.cuda.device_count())
    model.is_parallelizable = True
    model.model_parallel = True
# Out:
# 4

# %%
from transformers import TrainingArguments

args = TrainingArguments(
  output_dir = "Mixtral_Alpace_v3",
  #num_train_epochs=5,
  max_steps = 100, # comment out this line if you want to train in epochs
  per_device_train_batch_size = 10,
  warmup_steps = 0.03,
  logging_steps=10,
  save_strategy="epoch",
  #evaluation_strategy="epoch",
  evaluation_strategy="steps",
  eval_steps=10, # comment out this line if you want to evaluate at the end of each epoch
  learning_rate=2.5e-5,
  bf16=True,
  # lr_scheduler_type='constant',
)

# %% [markdown]
# Setting up the trainer.
#
# `max_seq_length`: Context window size

# %%
from trl import SFTTrainer

max_seq_length = 1024

trainer = SFTTrainer(
  model=model,
  peft_config=peft_config,
  max_seq_length=max_seq_length,
  tokenizer=tokenizer,
  packing=True,
  args=args,
  dataset_text_field="prompt",
  train_dataset=train_data,
  eval_dataset=test_data,
)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# /opt/app-root/lib64/python3.9/site-packages/trl/trainer/sft_trainer.py:267: UserWarning: You passed `packing=True` to the SFTTrainer, and you are training your model with `max_steps` strategy. The dataset will be iterated until the `max_steps` are reached.
#   warnings.warn(

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.float16.
#     <div>
#
#       <progress value='51' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 51/100 2:26:31 < 2:26:31, 0.01 it/s, Epoch 0.04/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.996500</td>
#       <td>0.960846</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.961100</td>
#       <td>0.904502</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.860100</td>
#       <td>0.857382</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.838200</td>
#       <td>0.827992</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='141' max='1525' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 141/1525 13:50 < 2:16:45, 0.17 it/s]
#     </div>

# %%
trainer.save_model("Mixtral_Alpace_v2")

# %% [markdown]
# # Save Model and Push to Hub

# %%
# !pip install huggingface-hub -qU

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %%
# trainer.push_to_hub("Promptengineering/mistral-instruct-generation")
trainer.push_to_hub("LLM-Alchemy-Chamber/mistral-instruct-gen-v4")

# %%
merged_model = model.merge_and_unload()

# %%
def generate_response(prompt, model):
  encoded_input = tokenizer(prompt,  return_tensors="pt", add_special_tokens=True)
  model_inputs = encoded_input.to('cuda')

  generated_ids = model.generate(**model_inputs,
                                 max_new_tokens=150,
                                 do_sample=True,
                                 pad_token_id=tokenizer.eos_token_id)

  decoded_output = tokenizer.batch_decode(generated_ids)

  return decoded_output[0]

# %%
prompt = "[INST]Use the provided input to create an instruction that could have been used to generate the response with an LLM.\nThere are more than 12,000 species of grass. The most common is Kentucky Bluegrass, because it grows quickly, easily, and is soft to the touch. Rygrass is shiny and bright green colored. Fescues are dark green and shiny. Bermuda grass is harder but can grow in drier soil.[/INST]"

# %%
generate_response(prompt, merged_model)

# %%
250*32
